# %%
import pandas as pd
import seaborn as sns
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
data_dict = datasets.load_diabetes(as_frame = True)
df = data_dict['data']
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
data_dict['target']
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %% [markdown]
# perform below mentioned dataframe operations on the data:
#     - add 2 synthetic columns with column name 'Name of Patient', 'Patient aadhaar number'
#     - write meaningful data to those columns ( based on real life examples )
#     - check for null values in the dataframe
#     - check and display the the count of null values in the dataframe under each column name
#     - try to modilfy the data for below cells with null values
#         - row 1, column 5
#         - row 2, column 3
#         - row 5, column 11
#         - row 96, column 5
#         - row 1, column 1
#     - now display the dataframe and observe the null values associated to each column
#     - display the count of null values in the datframe now ( i.e. after adding columns, modifying under synthetic new columns too )
#     - drop one of the column you have created i.e. 'Name of Patient'
#     - fill the null values in column 1 i.e. 'Age' with meaningful data based on the other values available in that column

# %%
df['target'] = data_dict['target']
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
# Dataset can be downloaded from this source
# https://www.kaggle.com/code/antoniofurioso/predict-diabetes-machine-learning-project
df = pd.read_table(r'C:\Users\vijet\Downloads\MDH Lab exercises\diabetes.tab.txt')
df = df.rename(columns={'AGE': 'age', 'SEX': 'sex', 'BMI':'bmi', 'BP':'bp','S1':'s1', 'S2':'s2', 'S3':'s3', 'S4':'s4', 'S5':'s5', 'S6':'s6', 'Y':'target'})
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Dataset can be downloaded from this source
#       2 # https://www.kaggle.com/code/antoniofurioso/predict-diabetes-machine-learning-project
# ----> 3 df = pd.read_table(r'C:\Users\vijet\Downloads\MDH Lab exercises\diabetes.tab.txt')
#       4 df = df.rename(columns={'AGE': 'age', 'SEX': 'sex', 'BMI':'bmi', 'BP':'bp','S1':'s1', 'S2':'s2', 'S3':'s3', 'S4':'s4', 'S5':'s5', 'S6':'s6', 'Y':'target'})
#       5 df.head()
#
# File c:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
plt.figure(figsize=(20, 7))

plt.subplot(1, 4, 1)
sns.histplot(df['age'], kde = True,color='r')
plt.title('Histogram')

# scatterplot
plt.subplot(1, 4, 2)
plt.scatter(df['age'],df['bp'],color = 'g')
plt.title('Scatterplot')


# boxplot
plt.subplot(1, 4, 3)
sns.boxplot(y=df['target'],color = 'b')
plt.title('Boxplot')

# barplot
plt.subplot(1, 4, 4)
sns.barplot(x='target', y = 'bmi', data = df)
plt.title('Barplot')

plt.show()

# %%
plt.hist(df['age'])
# Out:
# (array([19., 28., 47., 53., 55., 85., 69., 47., 33.,  6.]),
#  array([19., 25., 31., 37., 43., 49., 55., 61., 67., 73., 79.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['age'], bins=9)
# Out:
# (array([24., 34., 53., 54., 92., 72., 68., 39.,  6.]),
#  array([19.        , 25.66666667, 32.33333333, 39.        , 45.66666667,
#         52.33333333, 59.        , 65.66666667, 72.33333333, 79.        ]),
#  <BarContainer object of 9 artists>)

# %%
df['age'].min()
# Out:
# 19

# %%
df['age'].max()
# Out:
# 79

# %%
# more specific about the size of bins that you have, you can define them entirely. For example, if you wanted your bins to fall in five year increments
plt.hist(df['age'], bins=[0,5,10,15,20,25,35,40,45,50])
# Out:
# (array([ 0.,  0.,  0.,  3., 16., 59., 39., 44., 66.]),
#  array([ 0.,  5., 10., 15., 20., 25., 35., 40., 45., 50.]),
#  <BarContainer object of 9 artists>)

# %%
plt.hist(df['age'], log=True)
# Out:
# (array([19., 28., 47., 53., 55., 85., 69., 47., 33.,  6.]),
#  array([19., 25., 31., 37., 43., 49., 55., 61., 67., 73., 79.]),
#  <BarContainer object of 10 artists>)

# %%
# To change the alignment and color of the histogram
plt.hist(df['age'], bins=9, align='right', color='purple', edgecolor='black')
# Out:
# (array([24., 34., 53., 54., 92., 72., 68., 39.,  6.]),
#  array([19.        , 25.66666667, 32.33333333, 39.        , 45.66666667,
#         52.33333333, 59.        , 65.66666667, 72.33333333, 79.        ]),
#  <BarContainer object of 9 artists>)

# %%
# Pandas histograms can be applied to the dataframe directly, using the .hist() function
df.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'sex'}>,
#         <AxesSubplot: title={'center': 'bmi'}>],
#        [<AxesSubplot: title={'center': 'bp'}>,
#         <AxesSubplot: title={'center': 's1'}>,
#         <AxesSubplot: title={'center': 's2'}>],
#        [<AxesSubplot: title={'center': 's3'}>,
#         <AxesSubplot: title={'center': 's4'}>,
#         <AxesSubplot: title={'center': 's5'}>],
#        [<AxesSubplot: title={'center': 's6'}>,
#         <AxesSubplot: title={'center': 'target'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
df.hist(grid=False, bins=9)
# Out:
# array([[<AxesSubplot: title={'center': 'age'}>,
#         <AxesSubplot: title={'center': 'sex'}>,
#         <AxesSubplot: title={'center': 'bmi'}>],
#        [<AxesSubplot: title={'center': 'bp'}>,
#         <AxesSubplot: title={'center': 's1'}>,
#         <AxesSubplot: title={'center': 's2'}>],
#        [<AxesSubplot: title={'center': 's3'}>,
#         <AxesSubplot: title={'center': 's4'}>,
#         <AxesSubplot: title={'center': 's5'}>],
#        [<AxesSubplot: title={'center': 's6'}>,
#         <AxesSubplot: title={'center': 'target'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
# add titles and axis labels by using the following
df['age'].hist(grid=False, bins=9)
plt.xlabel('Age of Patients')
plt.ylabel('# of Patients')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %% [markdown]
# # Bar plots

# %%
x=df['age']
y=df['target']
plt.bar(x,y)
plt.show()

# %%
# The bar() and barh()
plt.barh(x, y)
plt.show()

# %%
x=df['age']
y=df['target']
plt.bar(x, y, color = "red")
plt.show()

# %%
# can use Hexadecimal color values
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
# The bar() takes the keyword argument width to set the width of the bars
plt.bar(x, y, width = 0.1)
plt.show()

# %%
# The barh() takes the keyword argument height to set the height of the bars
plt.barh(x, y, height = 0.5)
plt.show()

# why height is associated to barh() function only ?

# %%
# Documentation given here
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %% [markdown]
# # Stacked bar plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# data from https://allisonhorst.github.io/palmerpenguins/

species = (
    "Adelie\n $\\mu=$3700.66g",
    "Chinstrap\n $\\mu=$3733.09g",
    "Gentoo\n $\\mu=5076.02g$",
)
weight_counts = {
    "Below": np.array([70, 31, 58]),
    "Above": np.array([82, 37, 66]),
}
width = 0.5

fig, ax = plt.subplots()
bottom = np.zeros(3)

for boolean, weight_count in weight_counts.items():
    p = ax.bar(species, weight_count, width, label=boolean, bottom=bottom)
    bottom += weight_count

ax.set_title("Number of penguins with above average body mass")
ax.legend(loc="upper right")

plt.show()
