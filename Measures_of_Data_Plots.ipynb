# %% [markdown]
# ## Measure of Average

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.DataFrame({" rating": [1, 2, 3, 4, 6, 7, 9, 9, 9, 10], "dummy": range(10)})
df
# Out:
#     rating  dummy
# 0        1      0
# 1        2      1
# 2        3      2
# 3        4      3
# 4        6      4
# 5        7      5
# 6        9      6
# 7        9      7
# 8        9      8
# 9       10      9

# %%
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw= {"height_ratios": (0.2, 1)})
mean=df[' rating'].mean()
median=df[' rating'].median()
mode=df[' rating'].mode().values[0]

sns.boxplot(data=df, x=" rating", ax=ax_box)
ax_box.axvline(mean, color='r', linestyle='--')
ax_box.axvline(median, color='g', linestyle='-')
ax_box.axvline(mode, color='b', linestyle='-')

sns.histplot(data=df, x=" rating", ax=ax_hist, kde=True)
ax_hist.axvline(mean, color='r', linestyle='--', label="Mean")
ax_hist.axvline(median, color='g', linestyle='-', label="Median")
ax_hist.axvline(mode, color='b', linestyle='-', label="Mode")

ax_hist.legend()

ax_box.set(xlabel='')
plt.show()

# %% [markdown]
# ## Measure of Variance

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate some example data
data = np.random.normal(loc=0, scale=1, size=100)

# Calculate variance
variance = np.var(data)

# Data Visualization
plt.figure(figsize=(10, 6))

# Histogram of the data
plt.hist(data, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Example Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Add a vertical line at the mean
plt.axvline(np.mean(data), color='red', linestyle='dashed', linewidth=1, label='Mean')

# Add a vertical line at +/- 1 standard deviation from the mean
plt.axvline(np.mean(data) - np.std(data), color='green', linestyle='dashed', linewidth=1, label='-1 Std Dev')
plt.axvline(np.mean(data) + np.std(data), color='green', linestyle='dashed', linewidth=1, label='+1 Std Dev')

plt.legend()
plt.grid()
plt.show()

print(f"Variance: {variance:.2f}")
# Out:
# Variance: 0.90

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example exam scores
exam_scores = [85, 92, 78, 90, 88, 95, 85, 80, 82, 92]

# Calculate variance
variance = np.var(exam_scores)

# Data Visualization
plt.figure(figsize=(10, 6))

# Histogram of the exam scores
plt.hist(exam_scores, bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Exam Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')

# Add a vertical line at the mean
plt.axvline(np.mean(exam_scores), color='red', linestyle='dashed', linewidth=1, label='Mean')

# Add a vertical line at +/- 1 standard deviation from the mean
plt.axvline(np.mean(exam_scores) - np.std(exam_scores), color='green', linestyle='dashed', linewidth=1, label='-1 Std Dev')
plt.axvline(np.mean(exam_scores) + np.std(exam_scores), color='green', linestyle='dashed', linewidth=1, label='+1 Std Dev')

plt.legend()
plt.grid()
plt.show()

print(f"Variance: {variance:.2f}")
# Out:
# Variance: 28.61

# %% [markdown]
# ## Measure of Correlation

# %%
import numpy as np
from scipy.stats import pearsonr, spearmanr, kendalltau

# Example data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 6])

# Pearson correlation coefficient
pearson_corr, _ = pearsonr(x, y)

# Spearman rank correlation coefficient
spearman_corr, _ = spearmanr(x, y)

# Kendall tau rank correlation coefficient
kendall_corr, _ = kendalltau(x, y)

print(f"Pearson correlation: {pearson_corr:.2f}")
print(f"Spearman correlation: {spearman_corr:.2f}")
print(f"Kendall correlation: {kendall_corr:.2f}")
# Out:
# Pearson correlation: 0.85
# Spearman correlation: 0.82
# Kendall correlation: 0.74

# %% [markdown]
# ## Measure of ratio

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example data
periods = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
profits = [15000, 18000, 22000, 16000, 19000]

# Calculate the ratio of profit relative to the first period
base_profit = profits[0]
profit_ratios = [profit / base_profit for profit in profits]

# Data Visualization
plt.figure(figsize=(10, 6))

# Bar plot for profit ratios
plt.bar(periods, profit_ratios, color='skyblue')
plt.title('Profit Ratio by Period')
plt.xlabel('Period')
plt.ylabel('Profit Ratio')
plt.ylim(0, max(profit_ratios) * 1.2)  # Adjust the y-axis range

plt.grid()
plt.show()
